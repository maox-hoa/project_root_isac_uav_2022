# %%
# Out:
# ===== CHẠY MSTD =====
# E_tot = 40.0 kJ, eta = 0.5
# CU positions:
# [[1200. 1200.]
#  [1300.  800.]]
# ST true positions:
# [[1000. 1050.]
#  [ 300. 1050.]]
#
# [MSTD] Coarse estimate:
#   ST 0: true=[1000. 1050.], est=[1311.99099042  631.06977915] (err=522.3m)
#   ST 1: true=[ 300. 1050.], est=[ 215.34997559 1066.50956948] (err=86.2m)
#
# [MSTD] Stage 1: E=40.0kJ, Nf=60
#   iter 1: obj=0.082465 (Δ=+8.25e-02), ω*=0.060
#   iter 2: obj=0.082465 (Δ=+0.00e+00), ω*=0.000
#   Hội tụ tại iter 2.
#   Stage 1 trajectory: iters=2, obj=0.0825
#   ST 0: est=[ 998.6284093  1050.62926627], err=1.51m
#   ST 1: est=[ 299.98553885 1049.47540031], err=0.52m
#
# [MSTD] Stage 2: E=16.5kJ, Nf=60
#   iter 1: obj=0.756398 (Δ=+1.94e-01), ω*=0.970
#   iter 2: obj=0.788137 (Δ=+3.17e-02), ω*=0.240
#   iter 3: obj=0.829966 (Δ=+4.18e-02), ω*=0.310
#   iter 4: obj=0.840411 (Δ=+1.04e-02), ω*=0.090
#   iter 5: obj=0.840411 (Δ=+0.00e+00), ω*=0.000
#   Hội tụ tại iter 5.
#   Stage 2 trajectory: iters=5, obj=0.8404
# ...

# %%
# Out:
# ...
# MONTE CARLO SIMULATION - ISAC UAV Trajectory Optimization
# ...
# Number of runs: 50
# Number of processes: 16
# Energy budget: 40.0 kJ, eta: 0.5
# CU: 2, ST: 2
# Base seed: 42
# /home/hoa/PycharmProjects/project_root_isac_uav_2022/model_reconstructed/trajectory_optimizer.py:401: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   self.problem.solve(solver=solver, verbose=verbose)
# /home/hoa/PycharmProjects/project_root_isac_uav_2022/model_reconstructed/trajectory_optimizer.py:401: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   self.problem.solve(solver=solver, verbose=verbose)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       2 # PHÂN TÍCH NHANH PHÂN BỐ KẾT QUẢ MONTE CARLO (chạy ngay sau khi có `results`)
#       3 # ============================================================================
#       4
#       5 # Trích xuất dữ liệu từ `results` (list các dict)
# ----> 6 psi_c_vals = np.array([r["psi_c_final"] for r in results]) / 1e9      # Gbits
#       7 psi_s_vals = np.array([r["psi_s_final"] for r in results])            # m²
#       8 energy_vals = np.array([r["energy_consumed"] for r in results]) / 1e3 # kJ
#       9
#
# NameError: name 'results' is not defined
